# %% [markdown]
# #                                                        NETFLIX
# ##                                               NETFLIX DATA ANALYSIS PROJECT
#
#  Netflix is one of the most popular media and video streaming platforms. They have over 8000 movies or tv shows available on their platform, as of mid-2021, they have over 200M Subscribers globally. This tabular dataset consists of listings of all the movies and tv shows available on Netflix, along with details such as - cast, directors, ratings, release year, duration, etc.

# %%
# Importing the Dataset
import pandas as pd
data = pd.read_csv(r"C:\Users\Pratik Pandey\Downloads\archive\netflix_titles.csv") #to import pandas library and in bracket here we use small r because to remove uniquecode error

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# Getting some basic information about the DATASET

# %% [markdown]
# 1. head()

# %%
data.head()                       # to show top-5 records of the dataset
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# 2. tail()

# %%
data.tail()               # to show bottom-5 records of dataset
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# 3. shape

# %%
  data.shape              # to show the No. of Rows and Columns
# Out:
# (8807, 12)

# %% [markdown]
# 4. size

# %%
   data.size         # to show No. of total values(elements) in the dataset
# Out:
# 105684

# %% [markdown]
# 5. columns

# %%
data.columns          # to show each Column Name
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# 6. dtypes

# %%
data.dtypes            # to show the data-type of each column
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# 7. info()

# %%
data.info()            # To show indexes, columns, data-types of each column, memory at once
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# Task.1. Is there any Duplicate Record in this Dataset ? If yes, then remove the Duplicate Records.

# %% [markdown]
# duplicated()

# %%
data.duplicated()            # To check row wise and detect the duplicate rows
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
#In our dataset there is not any duplicate data. But if we found any duplicate data in our dataset to Remove the Duplicate rows permanently we use a commant "data.drop_duplicate()" 

data.drop_duplicate()   #if we run this command now then we found an error

# %%
#But from the command "data.drop_duplicate()" , It's not permanent, it's temporary. To make the changes in our dataset permanently , use the command "data.drop_duplicate(inplace = True)"

data.drop_duplicate(inplace = True)   # The changes are permanent now. Means the duplicate records are removed permanently.

# %% [markdown]
# Task.2. Is there any Null Value present in any column ? Show with Heat-Map

# %% [markdown]
# isnull()

# %%
data.isnull()          # To show where Null Value is presnt 

#if there is True then there is Null Value and If there is false then there is not null value
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
data.isnull().sum()              # To show the count of Null Values in each column
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# seaborn library (heat-map)

# %%
import seaborn as sns            # To import Seaborn library

# %%
sns.heatmap(data.isnull())               # Using heat-map to show null values count
# Out:
# <AxesSubplot:>

# %% [markdown]
# Now moving to the question part of this project

# %% [markdown]
# Q.1. For 'House of Cards', what is the Shoe Id and Who is the Director of this show ?
#
# This question is about getting all the data related to a particular element.
#
# So there are two methods to solve this question. First with the help of the fxn "isin()" and second with the help of the fxn "str.contains()"

# %% [markdown]
# isin()

# %%
 data['title']           # To show all records of a partcular item in any column
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: object

# %%
 data['title'].isin(['House of Cards'])      # To show all records of a partcular item in any column
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Name: title, Length: 8807, dtype: bool

# %%
data[ data['title'].isin(['House of Cards'])]       # To show all records of a partcular item in any column
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# str.contains()

# %%
data[data['title'].str.contains('House of Cards')]              #  To show all records of a particular string in any column
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# Q.2. In which year highest number of the TV Shows and Movies were released ? Show with Bar-Graph.
#
#
# This question is related to the date-time format.

# %% [markdown]
# dtypes
#
# first we need to check the datatype of our date-time column [Release date] (that's object datatype)

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
How to create a new column in existing table -> dataset_name['New_Column_Name'] = pd.The_Thing_Which_We_Want_In_Our_New_Column(Original_Column_Name_That_We_Want_To_Consider)

Ex- data['year_n'] = pd.to_datetime(data['release_year'])

# %% [markdown]
# to_datetime(argument)

# %%
data['year_n'] = pd.to_datetime(data['release_year'])   #We are creating a new column which will contain date-time format

# %%
.dt.year

# %%
data['YEAR'] = data['date_added'].dt.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-be7e820f203f> in <module>
# ----> 1 data['YEAR'] = data['date_added'].dt.year
#
# C:\ProgramData\Anaconda3\ANACONDA NEW DIRECTORY\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# C:\ProgramData\Anaconda3\ANACONDA NEW DIRECTORY\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
# ...

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# year_n          datetime64[ns]
# dtype: object

# %%
dt.year.value_counts()

.value_counts() fxn is used to count a repitive value in a particular column

# %%
data['release_year'].value_counts()  # It counts the occurance of all individual years in year column
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1966       1
# 1925       1
# 1947       1
# 1959       1
# 1961       1
# Name: release_year, Length: 74, dtype: int64

# %%
data['year_n'].dt.year.value_counts()
# Out:
# 1970    8807
# Name: year_n, dtype: int64

# %%
BAR GRAPH

Use function "countplot(argument)" which is related to a library seaborn

# %%
sns.countplot(data['release_year'])
# Out:
# C:\ProgramData\Anaconda3\ANACONDA NEW DIRECTORY\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='release_year', ylabel='count'>

# %%
# Error code. Need to rectify it ASAP

data['release_year'].value_counts().plot(x, y, Kind='bar')

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
# Error code. Need to rectify it ASAP

plt.bar(data['release_year'],data['release_year'].value_counts())
plt.show

# %%
Q.3. How many Movies and TV Shows are in the dataset ? Show with Bar-Graph

# %%
groupby(argument)

# %%
data.groupby('type')     #To group all unique items of a column and show their count

# %%
data.groupby('type').type.count()   #To group all unique items of a column and show their count
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
sns.countplot(data['type'])   # To show the count of all unique values of any column in the form of bar graph
# Out:
# C:\ProgramData\Anaconda3\ANACONDA NEW DIRECTORY\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='count'>

# %% [markdown]
# Q.4. Show all the Movies that were released in year 2000

# %%
Filtering

# %% [markdown]
# So first of all we will apply filtering for first condition only that's for Movies and then apply filtering for our second condition thatis Year.

# %%
# data[ (data['type']=='Movie') & (data['release_year']==2000)]

data[ (data['type']=='Movie') & (data['release_year']==2000)]
# Out:
#      show_id   type                                              title  \
# 180     s181  Movie                 The Nutty Professor II: The Klumps
# 350     s351  Movie                                      Space Cowboys
# 359     s360  Movie                       The Original Kings of Comedy
# 566     s567  Movie                                   Charlie's Angels
# 593     s594  Movie                                           Snow Day
# 779     s780  Movie                                  Battlefield Earth
# 952     s953  Movie                               The Whole Nine Yards
# 3472   s3473  Movie                        Rugrats in Paris: The Movie
# 4545   s4546  Movie             Monty Python: Before the Flying Circus
# 4723   s4724  Movie                                               Fiza
# 4956   s4957  Movie                        Phir Bhi Dil Hai Hindustani
# 5953   s5954  Movie                             Joseph: King of Dreams
# ...

# %%
data[ (data['type']=='Movie') & (data['release_year']==1980)]
# Out:
#      show_id   type                                    title  \
# 175     s176  Movie                          The Blue Lagoon
# 605     s606  Movie                          The Long Riders
# 1831   s1832  Movie                                 Whispers
# 2723   s2724  Movie                               Friendship
# 5079   s5080  Movie                      Alibaba Aur 40 Chor
# 7188   s7189  Movie                               Khubsoorat
# 7752   s7753  Movie                         Playing for Time
# 7755   s7756  Movie                                   Popeye
# 7820   s7821  Movie                              Raging Bull
# 7860   s7861  Movie               Return To The 36th Chamber
# 8142   s8143  Movie  Sword Masters: Two Champions of Shaolin
#
#                          director  \
# 175                Randal Kleiser
# 605                   Walter Hill
# 1831              Maroun Baghdadi
# 2723                   Raj Khosla
# 5079  Latif Faiziyev, Umesh Mehra
# ...

# %% [markdown]
# Q.5. Show only the Titles of all TV Shows that were released in India only.

# %%
Filtering

# %%
data[ (data['type']=='TV Show') & (data['country']=='India')]
# Out:
#      show_id     type                               title director  \
# 4         s5  TV Show                        Kota Factory      NaN
# 39       s40  TV Show                        Chhota Bheem      NaN
# 50       s51  TV Show                       Dharmakshetra      NaN
# 66       s67  TV Show       Raja Rasoi Aur Anya Kahaniyan      NaN
# 69       s70  TV Show      Stories by Rabindranath Tagore      NaN
# ...      ...      ...                                 ...      ...
# 8173   s8174  TV Show                           Thackeray      NaN
# 8235   s8236  TV Show                         The Calling    Bumpy
# 8321   s8322  TV Show  The Golden Years with Javed Akhtar      NaN
# 8349   s8350  TV Show              The House That Made Me      NaN
# 8775   s8776  TV Show                     Yeh Meri Family      NaN
#
#                                                    cast country  \
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
# ...

# %%
But the question is asking for show only TV Shows and Country = India...Not every details

# %%
data[ (data['type']=='TV Show') & (data['country']=='India')] ['title']
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %% [markdown]
# Q.6. Show Top 10 Directors, who gave the highest number of TV Shows and Movies to Netflix.

# %%
value_counts()

# %%
# data['director'].value_counts()

data['director'].value_counts()
# Out:
# Rajiv Chilaka               19
# Raúl Campos, Jan Suter      18
# Marcus Raboy                16
# Suhas Kadav                 16
# Jay Karas                   14
#                             ..
# Mick Grogan                  1
# Johnny Kevorkian             1
# John Smithson                1
# Mark Sloper                  1
# Cody Cameron, Kris Pearn     1
# Name: director, Length: 4528, dtype: int64

# %%
data['director'].value_counts().head(10)    #Question is asking for top 10 directors
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %% [markdown]
# Q.7. Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom"

# %%
Filtering (And, Or Operators)

# %%
data[(data['type']=='Movie') & (data['listed_in']=='Comedies')]
# Out:
#      show_id   type                                   title  \
# 27       s28  Movie                               Grown Ups
# 152     s153  Movie           Janoskians: Untold and Untrue
# 182     s183  Movie             Welcome Home Roscoe Jenkins
# 342     s343  Movie                             Major Payne
# 348     s349  Movie                                    Poms
# ...      ...    ...                                     ...
# 8420   s8421  Movie              The Men Who Stare at Goats
# 8433   s8434  Movie  The Naked Gun 2 1/2: The Smell of Fear
# 8536   s8537  Movie                       The Trip to Spain
# 8608   s8609  Movie                        Total Frat Movie
# 8730   s8731  Movie                       Where's the Money
#
#                   director                                               cast  \
# 27            Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# 152           Brett Weiner  Jai Brooks, Luke Brooks, James Yammouni, Danie...
# ...

# %%
#using 3rd condition also which is country of United Kingdom

data[(data['type']=='Movie') & (data['listed_in']=='Comedies') | (data['country']=='United kingdom')]
# Out:
#      show_id   type                                   title  \
# 27       s28  Movie                               Grown Ups
# 152     s153  Movie           Janoskians: Untold and Untrue
# 182     s183  Movie             Welcome Home Roscoe Jenkins
# 342     s343  Movie                             Major Payne
# 348     s349  Movie                                    Poms
# ...      ...    ...                                     ...
# 8420   s8421  Movie              The Men Who Stare at Goats
# 8433   s8434  Movie  The Naked Gun 2 1/2: The Smell of Fear
# 8536   s8537  Movie                       The Trip to Spain
# 8608   s8609  Movie                        Total Frat Movie
# 8730   s8731  Movie                       Where's the Money
#
#                   director                                               cast  \
# 27            Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# 152           Brett Weiner  Jai Brooks, Luke Brooks, James Yammouni, Danie...
# ...

# %% [markdown]
# Q.8. In how many movies/shows, Tom Cruise was cast ?

# %%
Filtering

# %%
data[data['cast']=='Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, year_n]
# Index: []

# %% [markdown]
# the above code is not working because there is not any row in which tom cruise is alone, means along with tom cruise there are some other cast also. so need to use some other function in which any row containing tom cruise shows the result irrespective of if some other casts are also present there.

# %%
data[data['cast']=='Kevin James']
# Out:
#      show_id   type                               title      director  \
# 4092   s4093  Movie  Kevin James: Sweat the Small Stuff   Paul Miller
# 4919   s4920  Movie    Kevin James: Never Don't Give Up  Andy Fickman
#
#              cast        country         date_added  release_year rating  \
# 4092  Kevin James  United States  February 20, 2019          2001  TV-PG
# 4919  Kevin James  United States     April 24, 2018          2018  TV-PG
#
#      duration        listed_in  \
# 4092   42 min  Stand-Up Comedy
# 4919   62 min  Stand-Up Comedy
#
#                                             description  \
# 4092  The film and television star riffs on life's m...
# 4919  Kevin James makes his long-awaited return to s...
#
#                             year_n
# 4092 1970-01-01 00:00:00.000002001
# 4919 1970-01-01 00:00:00.000002018

# %%
str.contains(arguments)

# %%
data[data['cast'].str.contains('Kevin James')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-a4e661d33c5d> in <module>
# ----> 1 data[data['cast'].str.contains('Kevin James')]
#
# C:\ProgramData\Anaconda3\ANACONDA NEW DIRECTORY\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3012
#    3013         # Do we have a (boolean) 1d indexer?
# -> 3014         if com.is_bool_indexer(key):
#    3015             return self._getitem_bool_array(key)
#    3016
#
# C:\ProgramData\Anaconda3\ANACONDA NEW DIRECTORY\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     112                     # Don't raise on e.g. ["A", "B", np.nan], see
#     113                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 114                     raise ValueError(na_msg)
#     115                 return False
#     116             return True
#
# ...

# %% [markdown]
# Here the above error is "Cannot mask with non-boolean array containing NA / NaN values" which means this function (str.contains()) cannot work on the null values or missing values. First we will try to remove this null values then find the answer

# %%
Creating new data-frame

# data_new = data.dropna()    #drop_na #It drops the rows that contains all or any missing values.

# %%
data_new = data.dropna()  #after removing all the null values from our dataset, we will save our new dataset which doesn't have any null value in data_new

# %%
data_new.head(4)
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country          date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                      United Kingdom  September 24, 2021
# 9                                       United States  September 24, 2021
# ...

# %%
data_new[data_new['cast'].str.contains('Kevin James')]
# Out:
#      show_id   type                                      title  \
# 27       s28  Movie                                  Grown Ups
# 1616   s1617  Movie                              Monster House
# 1879   s1880  Movie                            Hubie Halloween
# 4092   s4093  Movie         Kevin James: Sweat the Small Stuff
# 4919   s4920  Movie           Kevin James: Never Don't Give Up
# 5533   s5534  Movie                               Sandy Wexler
# 5719   s5720  Movie  True Memoirs of an International Assassin
# 6977   s6978  Movie                                      Hitch
# 7008   s7009  Movie      Hotel Transylvania 3: Summer Vacation
# 7716   s7717  Movie                       Paul Blart: Mall Cop
#
#                 director                                               cast  \
# 27          Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# 1616           Gil Kenan  Mitchel Musso, Sam Lerner, Spencer Locke, Stev...
# ...

# %%
data_new[data_new['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#           date_added  release_year rating duration  \
# 341   August 1, 2021          1999      R  189 min
# 1254   March 1, 2021          1988      R  134 min
#
#                        listed_in  \
# 341   Dramas, Independent Movies
# 1254      Classic Movies, Dramas
#
#                                             description  \
# 341   Through chance, history and divine interventio...
# 1254  Motivated by money, a selfish workaholic seeki...
#
#                             year_n
# 341  1970-01-01 00:00:00.000001999
# 1254 1970-01-01 00:00:00.000001988

# %% [markdown]
# Q.9. What are the different Ratings defined by Netflix ?

# %%
nunique()    # it's used to count the different ratings

# data.rating.nunique()

# %%
data.rating.nunique()  # So there are 17 different ratings which are used by Netflix
# Out:
# 17

# %%
data['rating'].nunique()
# Out:
# 17

# %%
#Show that 17 different ratings

use function "unique()"

data.rating.unique()

# %%
data.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
data['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# Q.9.1. How many Movies got the 'TV-14' rating, in Canada ?

# %%
Filtering

# %%
data[(data['type']=='Movie') & (data['rating']=='TV-14')]
# Out:
#      show_id   type                                              title  \
# 18       s19  Movie                                          Intrusion
# 24       s25  Movie                                              Jeans
# 30       s31  Movie                                    Ankahi Kahaniya
# 51       s52  Movie  InuYasha the Movie 2: The Castle Beyond the Lo...
# 52       s53  Movie  InuYasha the Movie 3: Swords of an Honorable R...
# ...      ...    ...                                                ...
# 8772   s8773  Movie                              Yamla Pagla Deewana 2
# 8774   s8775  Movie                                          يوم الدين
# 8794   s8795  Movie                                             اشتباك
# 8799   s8800  Movie                                              Zenda
# 8806   s8807  Movie                                             Zubaan
#
#                                                director  \
# 18                                           Adam Salky
# ...

# %%
data[(data['type']=='Movie') & (data['rating']=='TV-14') & (data['country']=='Canada')]
# Out:
#      show_id   type                                        title  \
# 157     s158  Movie                                     Level 16
# 1279   s1280  Movie   Made You Look: A True Story About Fake Art
# 2769   s2770  Movie               There's Something in the Water
# 3424   s3425  Movie  Martin Matte: La vie, la mort...eh la la..!
# 5972   s5973  Movie                             #cats_the_mewvie
# 5973   s5974  Movie                                        #Roxy
# 6192   s6193  Movie                               At First Light
# 6537   s6538  Movie                   Counterfeiting in Suburbia
# 7334   s7335  Movie                            Long Time Running
# 7916   s7917  Movie                   Sadie's Last Days on Earth
# 7936   s7937  Movie                                   Sardaar ji
# 8178   s8179  Movie                  The Accountant of Auschwitz
# 8566   s8567  Movie                         The Wrong Babysitter
#
#                                     director  \
# ...

# %%
data[(data['type']=='Movie') & (data['rating']=='TV-14') & (data['country']=='Canada')].shape
# Out:
# (13, 13)

# %% [markdown]
# Q.9.2 How many TV Shows got the 'R' rating, after year 2018 ?

# %%
data[(data['type']=='TV Shows') & (data['rating']=='R')]  # zero TV Shows
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, year_n]
# Index: []

# %% [markdown]
# Q.9.3 How many Movies got the 'R' rating, after year 2018 ?

# %%
data[(data['type']=='Movie') & (data['rating']=='R')]
# Out:
#      show_id   type                        title  \
# 46       s47  Movie                   Safe House
# 48       s49  Movie                 Training Day
# 81       s82  Movie                         Kate
# 122     s123  Movie                   In the Cut
# 131     s132  Movie  Blade Runner: The Final Cut
# ...      ...    ...                          ...
# 8765   s8766  Movie                           XX
# 8768   s8769  Movie            Y Tu Mamá También
# 8791   s8792  Movie                  Young Adult
# 8802   s8803  Movie                       Zodiac
# 8804   s8805  Movie                   Zombieland
#
#                                                director  \
# 46                                      Daniel Espinosa
# 48                                        Antoine Fuqua
# 81                                Cedric Nicolas-Troyan
# 122                                        Jane Campion
# 131                                        Ridley Scott
# ...

# %%
data[(data['type']=='Movie') & (data['rating']=='R') & (data['release_year']>2018)]
# Out:
#      show_id   type                        title               director  \
# 81       s82  Movie                         Kate  Cedric Nicolas-Troyan
# 214     s215  Movie  SAS: Rise of the Black Swan         Magnus Martens
# 247     s248  Movie                   Sweet Girl   Brian Andrew Mendoza
# 363     s364  Movie                    The Vault        Jaume Balagueró
# 437     s438  Movie                   Cosmic Sin           Edward Drake
# ...      ...    ...                          ...                    ...
# 6286   s6287  Movie           Berlin, I Love You                    NaN
# 6623   s6624  Movie                       Domino         Brian De Palma
# 6682   s6683  Movie            Elizabeth Harvest    Sebastian Gutierrez
# 6713   s6714  Movie              Everybody Knows         Asghar Farhadi
# 7950   s7951  Movie                   Saving Zoë        Jeffrey G. Hunt
#
#                                                    cast  \
# ...

# %%
data[(data['type']=='Movie') & (data['rating']=='R') & (data['release_year']>2018)].shape
# Out:
# (108, 13)

# %% [markdown]
# Q.10. What is the maximum duration of a Movie/Show on Netflix ?

# %%
data.duration.unique()  # data['duration'].unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %% [markdown]
# so here see above that some durations are in minutes and some durations are in seasons.
# so for our question we are considering only minutes.

# %% [markdown]
# Here the datatype of our duration is in object type. So first we need to convert this object datatype of duration into numeric datatype.

# %%
str.split(argument)   # to create two different columns from a single column we will use str.split() fxn

# %% [markdown]
# so first we break our duration into two parts that's first one is in numeric number value and second one is in string value

# %%
# data[['first_colummnNAME', 'second_columnNAME']] = data['Splitting_columnNAME'].str.split()

data[['Minutes', 'Unit']] = data['duration'].str.split(' ', expand = True)

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
#
#                          year_n Minutes     Unit
# ...

# %% [markdown]
# So in above table we can see that the duration column is splitted into two different columns that's Minutes and Unit , at last the two columns are shown.

# %%
max()

# %%
data['Minutes']
# Out:
# 0        90
# 1         2
# 2         1
# 3         1
# 4         2
#        ...
# 8802    158
# 8803      2
# 8804     88
# 8805     88
# 8806    111
# Name: Minutes, Length: 8807, dtype: object

# %%
# Error Code. Rectify it ASAP (may be the error is due to the string or float value present in Minutes column)

data['Minutes'].max()

# %%
# Error Code. Rectify it ASAP

data['Minutes'].min()

# %% [markdown]
# Q.11. Which individual country has the Highest No. of TV Shows ?

# %% [markdown]
# So here we are creating a new dataframe which will contain only the TV SHows

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
#
#                          year_n Minutes     Unit
# ...

# %%
data_tvshow = data[data['type'] == 'TV Show']

# %%
data_tvshow.head(2)
# Out:
#   show_id     type          title         director  \
# 1      s2  TV Show  Blood & Water              NaN
# 2      s3  TV Show      Ganglands  Julien Leclercq
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description  \
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
#
#                          year_n Minutes     Unit
# 1 1970-01-01 00:00:00.000002021       2  Seasons
# ...

# %%
data_tvshow.country.value_counts()
# Out:
# United States                                     760
# United Kingdom                                    213
# Japan                                             169
# South Korea                                       158
# India                                              79
#                                                  ...
# United Kingdom, Germany, United States, France      1
# Norway, Germany, Sweden                             1
# United Kingdom, Singapore                           1
# Saudi Arabia, Syria, Egypt, Lebanon, Kuwait         1
# United States, Netherlands, Japan, France           1
# Name: country, Length: 196, dtype: int64

# %%
#For individual country having highest number of TV Shows

data_tvshow.country.value_counts().head(1)
# Out:
# United States    760
# Name: country, dtype: int64

# %% [markdown]
# Q.12. How can we sort the dataset by Year ?

# %%
Function

.sort_values(by='')

# %%
data.sort_values(by='release_year').head(2)
# Out:
#      show_id     type                              title     director cast  \
# 4250   s4251  TV Show  Pioneers: First Women Filmmakers*          NaN  NaN
# 7790   s7791    Movie                     Prelude to War  Frank Capra  NaN
#
#             country         date_added  release_year rating  duration  \
# 4250            NaN  December 30, 2018          1925  TV-14  1 Season
# 7790  United States     March 31, 2017          1942  TV-14    52 min
#
#                           listed_in  \
# 4250                       TV Shows
# 7790  Classic Movies, Documentaries
#
#                                             description  \
# 4250  This collection restores films from women who ...
# 7790  Frank Capra's documentary chronicles the rise ...
#
#                             year_n Minutes    Unit
# 4250 1970-01-01 00:00:00.000001925       1  Season
# 7790 1970-01-01 00:00:00.000001942      52     min

# %%
data.sort_values(by='release_year', ascending=False).head(2)
# Out:
#     show_id   type                                  title        director  \
# 693    s694  Movie                 Ali & Ratu Ratu Queens  Lucky Kuswandi
# 781    s782  Movie  Black Holes | The Edge of All We Know   Peter Galison
#
#                                                   cast country     date_added  \
# 693  Iqbaal Ramadhan, Nirina Zubir, Asri Welas, Tik...     NaN  June 17, 2021
# 781                                                NaN     NaN   June 2, 2021
#
#      release_year rating duration                               listed_in  \
# 693          2021  TV-14  101 min  Comedies, Dramas, International Movies
# 781          2021  TV-14   99 min                           Documentaries
#
#                                            description  \
# 693  After his father's passing, a teenager sets ou...
# 781  Follow scientists on their quest to understand...
#
#                            year_n Minutes Unit
# 693 1970-01-01 00:00:00.000002021     101  min
# ...

# %% [markdown]
# Q.13. Find all the instances where
#
# Category is 'Movie' and Type is 'Dramas'
#
# or
#
# Category is 'TV Show' and Type is 'Reality TV'

# %%
data[(data['type']=='Movie') & (data['listed_in']=='Dramas')]
# Out:
#      show_id   type                title             director  \
# 112     s113  Movie                Worth       Sara Colangelo
# 129     s130  Movie   An Unfinished Life      Lasse Hallström
# 142     s143  Movie      Freedom Writers  Richard LaGravenese
# 162     s163  Movie             Marshall      Reginald Hudlin
# 329     s330  Movie  Catch Me If You Can     Steven Spielberg
# ...      ...    ...                  ...                  ...
# 8674   s8675  Movie      Viceroy's House      Gurinder Chadha
# 8675   s8676  Movie               Victor    Brandon Dickerson
# 8685   s8686  Movie                  VS.             Ed Lilly
# 8691   s8692  Movie            Wakefield        Robin Swicord
# 8696   s8697  Movie            War Horse     Steven Spielberg
#
#                                                    cast  \
# 112   Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129   Robert Redford, Jennifer Lopez, Morgan Freeman...
# ...

# %%
data[(data['type']=='TV Show') & (data['listed_in']=='Reality TV')]
# Out:
#      show_id     type                                      title director  \
# 55       s56  TV Show                                  Nailed It      NaN
# 74       s75  TV Show  The World's Most Amazing Vacation Rentals      NaN
# 83       s84  TV Show                         Metal Shop Masters      NaN
# 95       s96  TV Show                                 The Circle      NaN
# 147     s148  TV Show                         How to Be a Cowboy      NaN
# ...      ...      ...                                        ...      ...
# 8040   s8041  TV Show                             Slobby's World      NaN
# 8376   s8377  TV Show                       The Kindness Diaries      NaN
# 8474   s8475  TV Show                               The Rap Game      NaN
# 8605   s8606  TV Show                                  Top Grier      NaN
# 8747   s8748  TV Show                                  Winsanity      NaN
#
#                              cast                        country  \
# ...

# %%
data[(data['type']=='Movie') & (data['listed_in']=='Dramas') | (data['type']=='TV Show') & (data['listed_in']=='Reality TV')]
# Out:
#      show_id     type                                      title  \
# 55       s56  TV Show                                  Nailed It
# 74       s75  TV Show  The World's Most Amazing Vacation Rentals
# 83       s84  TV Show                         Metal Shop Masters
# 95       s96  TV Show                                 The Circle
# 112     s113    Movie                                      Worth
# ...      ...      ...                                        ...
# 8675   s8676    Movie                                     Victor
# 8685   s8686    Movie                                        VS.
# 8691   s8692    Movie                                  Wakefield
# 8696   s8697    Movie                                  War Horse
# 8747   s8748  TV Show                                  Winsanity
#
#                director                                               cast  \
# 55                  NaN                        Nicole Byer, Jacques Torres
# ...

# %%
data[(data['type']=='TV Show') & (data['listed_in']=="Kids' TV")]
# Out:
#      show_id     type                    title director  \
# 34       s35  TV Show  Tayo and Little Wizards      NaN
# 39       s40  TV Show             Chhota Bheem      NaN
# 65       s66  TV Show             Numberblocks      NaN
# 89       s90  TV Show              Mighty Raju      NaN
# 100     s101  TV Show  Tobot Galaxy Detectives      NaN
# ...      ...      ...                      ...      ...
# 8669   s8670  TV Show            V.R. Troopers      NaN
# 8679   s8680  TV Show       ViR: The Robot Boy      NaN
# 8783   s8784  TV Show                     Yoko      NaN
# 8785   s8786  TV Show                      YOM      NaN
# 8797   s8798  TV Show                Zak Storm      NaN
#
#                                                    cast  \
# 34    Dami Lee, Jason Lee, Bommie Catherine Han, Jen...
# 39    Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...
# 65    Beth Chalmers, David Holt, Marcel McCalla, Ter...
# 89    Julie Tejwani, Sabina Malik, Jigna Bhardwaj, R...
# ...
